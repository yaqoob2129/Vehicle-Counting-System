# %%
pip install -r requirement.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'C:\Users\Muhammad' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#               filename  width  height       class  xmin  ymin  xmax  ymax
# 0  train/frame1756.jpg   1280     720  motorcycle   461   461   437   720
# 1  train/frame1756.jpg   1280     720  motorcycle   187   187   887   337
# 2  train/frame1756.jpg   1280     720  motorcycle   246   246   777   441
# 3  train/frame1756.jpg   1280     720         car   157   157   422   241
# 4  train/frame1756.jpg   1280     720  motorcycle   145   145   519   226

# %%
#reading single image using imread function of matplotlib
image = plt.imread('Dataset/images/train/frame873.jpg')
plt.imshow(image)

# %%
# Number of unique training images
train['filename'].nunique()
# Out:
# 177

# %%
# Number of classes
train['class'].value_counts()
# Out:
# car           612
# motorcycle    576
# truck          86
# bus             3
# Name: class, dtype: int64
